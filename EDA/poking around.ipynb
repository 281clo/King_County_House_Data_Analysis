# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
# %matplotlib inline

# %%
# read the data
df = pd.read_csv('data/kc_house_data.csv')

# %%
#looking at data
df.head(40)
# Out:
#             id        date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  10/13/2014   221900.0         3       1.00         1180
# 1   6414100192   12/9/2014   538000.0         3       2.25         2570
# 2   5631500400   2/25/2015   180000.0         2       1.00          770
# 3   2487200875   12/9/2014   604000.0         4       3.00         1960
# 4   1954400510   2/18/2015   510000.0         3       2.00         1680
# 5   7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6   1321400060   6/27/2014   257500.0         3       2.25         1715
# 7   2008000270   1/15/2015   291850.0         3       1.50         1060
# 8   2414600126   4/15/2015   229500.0         3       1.00         1780
# 9   3793500160   3/12/2015   323000.0         3       2.50         1890
# 10  1736800520    4/3/2015   662500.0         3       2.50         3560
# 11  9212900260   5/27/2014   468000.0         2       1.00         1160
# ...

# %%
#Rows, Columns
print(df.shape)
# Out:
# (21597, 21)

# %%
#summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
# select numeric columns
df_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
print(numeric_cols)
# Out:
# ['id' 'price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot' 'floors'
#  'sqft_above' 'yr_built' 'yr_renovated' 'zipcode' 'lat' 'long'
#  'sqft_living15' 'sqft_lot15']

# %%
# select non numeric columns
df_non_numeric = df.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print(non_numeric_cols)
# Out:
# ['date' 'waterfront' 'view' 'condition' 'grade' 'sqft_basement']

# %%
df['yr_renovated'].head()
# Out:
# 0       0.0
# 1    1991.0
# 2       NaN
# 3       0.0
# 4       0.0
# Name: yr_renovated, dtype: float64

# %%
#looking at year rennovated to see what data is in there. 

df['yr_renovated'].value_counts() #can we assume that 0 means the place has never been rennovated?
# Out:
# 0.0       17011
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
#           ...
# 1946.0        1
# 1959.0        1
# 1971.0        1
# 1951.0        1
# 1954.0        1
# Name: yr_renovated, Length: 70, dtype: int64

# %% [markdown]
# ## Data Cleaning Starts Here

# %%
# all correlations: 
testing=df.corr().abs().stack().reset_index().sort_values(0, ascending=False)
testing.head(30)
# Out:
#            level_0        level_1         0
# 0               id             id  1.000000
# 16           price          price  1.000000
# 208  sqft_living15  sqft_living15  1.000000
# 192           long           long  1.000000
# 176            lat            lat  1.000000
# 160        zipcode        zipcode  1.000000
# 144   yr_renovated   yr_renovated  1.000000
# 128       yr_built       yr_built  1.000000
# 96          floors         floors  1.000000
# 80        sqft_lot       sqft_lot  1.000000
# 64     sqft_living    sqft_living  1.000000
# 48       bathrooms      bathrooms  1.000000
# 32        bedrooms       bedrooms  1.000000
# 112     sqft_above     sqft_above  1.000000
# 224     sqft_lot15     sqft_lot15  1.000000
# 109     sqft_above    sqft_living  0.876448
# 67     sqft_living     sqft_above  0.876448
# 73     sqft_living  sqft_living15  0.756402
# 199  sqft_living15    sqft_living  0.756402
# 63     sqft_living      bathrooms  0.755758
# ...

# %%
import seaborn as sns
plt.subplots(figsize=(15,15))
sns.heatmap(df.corr(), center=0, annot=True, cmap="coolwarm", annot_kws={"size":10})
# Out:
# <AxesSubplot:>

# %%
plot the kde over a histogram this way: 

for column in df:
    df[column].plot.hist(density=True, label = column+' histogram')
    df[column].plot.kde(label =column+' kde')
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-f444f7071cea> in <module>
#       2
#       3 for column in df:
# ----> 4     df[column].plot.hist(density=True, label = column+' histogram')
#       5     df[column].plot.kde(label =column+' kde')
#       6     plt.legend()
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/plotting/_core.py in hist(self, by, bins, **kwargs)
#    1288             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1289         """
# -> 1290         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1291
#    1292     def kde(self, bw_method=None, ind=None, **kwargs):
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# ...

# %%
# pretend model using price and sqft living

from statsmodels.formula.api import ols

f = 'price ~ sqft_living15' #formula

model = ols(formula=f, data=df).fit() #model

model.summary() #summary results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.343
# Model:                            OLS   Adj. R-squared:                  0.342
# Method:                 Least Squares   F-statistic:                 1.125e+04
# Date:                Sun, 03 Oct 2021   Prob (F-statistic):               0.00
# Time:                        15:13:40   Log-Likelihood:            -3.0286e+05
# No. Observations:               21597   AIC:                         6.057e+05
# Df Residuals:                   21595   BIC:                         6.057e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...
